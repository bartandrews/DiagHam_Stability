# %%
import numpy as np
import scipy.linalg
import math
import sys
import matplotlib.pyplot as plt
import json

# %% [markdown]
# # Quartic EM Response: Current per Orbital: Direct Numerics
# [Adapted from David's higher-order-hamiltonian Jupyter notebook]

# %% [markdown]
# The following gives us the spectrum of effective continuum hamiltonians by truncating to finite-dimensional matrices. Set `trunc_dim` to the dimension of matrices we work with (50 seems to work fine).

# %% [markdown]
# ## Hamiltonian Diagonalization

# %%
trunc_dim = 100

# %%
#initialize hamiltonian with zeroes
ham = np.matrix(np.zeros(shape=(trunc_dim,trunc_dim)),dtype=complex)
# Landau hamiltonian
h0 = np.diag(np.arange(trunc_dim)+0.5)
# squared ladder operators
f = np.vectorize(lambda x: math.sqrt(x*(x-1)))
g = np.vectorize(lambda x: math.sqrt((x+1)*(x+2)))
a2 = np.diag(f(np.arange(2,trunc_dim)),-2)
at2 = np.diag(g(np.arange(trunc_dim-2)),2)
# squared momenta
px2 = h0 - 0.5*(a2+at2)
py2 = h0 + 0.5*(a2+at2)

# %%
## Single Ladder Operators

f1 = np.vectorize(lambda x: math.sqrt(x))
g1 = np.vectorize(lambda x: math.sqrt(x+1))
                  
a1 = np.diag(f1(np.arange(1,trunc_dim)),-1)
at1 = np.diag(g1(np.arange(trunc_dim-1)),1)

py1 = -1/np.sqrt(2)*(a1+at1)

# %% [markdown]
# Let's add some functions that give us $p_x^{2n}$ and $p_y^{2n}$ recursively and store previous results

# %%
# returns matrix rep of px^(2n) using memoization to store results.
px2n_table = [0,px2]
def px2n(n):
    if(len(px2n_table)>n):
        return px2n_table[n]
    else:
        temp = px2n(n-1)@px2
        px2n_table.append(temp)
        return temp
    
# matrix rep of py^(2n)
py2n_table = [0,py2]
def py2n(n):
    if(len(py2n_table)>n):
        return py2n_table[n]
    else:
        temp = py2n(n-1)@py2
        py2n_table.append(temp)
        return temp

# %%
# Calculate odd powers of py

#matrix rep of py^(2n-1)
def pyn_odd(n):
    if((n%2)==1):
        if(n==1):
            return py1
        else:
            return py2n((n-1)//2) @ py1
    else:
        print('Error: n not odd')

# %% [markdown]
# Now we implement the hamiltonian $H_{\text{eff}}^{(n)} = \frac{1}{2n}\left(\pi_x^{2n} + \pi_y^{2n}\right)$

# %%
def p_power_Heff(n):
    return 0.5*(1/n)*(px2n(n) + py2n(n))

def find_evals_evec(n):
    q_evals,q_evecs =scipy.linalg.eigh(p_power_Heff(n))
    return q_evals,q_evecs

# %% [markdown]
# ## Define and calculate matrix elements

# %%
def current_op(n):
    return pyn_odd(2*n-1)

def potential_term(p):
    if (p%2==0):
        return py2n(p//2)
    else:
        return pyn_odd(p)

# %%
def matrix_elem(state_l, state_r, operator):
    return np.conjugate(state_l) @ operator @ state_r

# %% [markdown]
# ## Calculate Current Per Orbital

# %%
def current_per_orbital_n_p_lam(n, p, lam, evals, evecs, mu_cutoff=10):
    
    mu_range = np.array([j for j in range(mu_cutoff)])
    mu_range = np.delete(mu_range, lam)
        
    current_orbital_out = 0
    
    for mu in mu_range:
        current_orbital_out += (matrix_elem(evecs[:,lam], evecs[:,mu], current_op(n))*
                                matrix_elem(evecs[:,mu], evecs[:,lam], potential_term(p))/
                               (evals[lam]-evals[mu]))
    
    return -2*current_orbital_out

# %%
def write_current_per_orbital(n_max, p_max, lam_max, mu_cutoff=20):
    
    for n in range(1,n_max+1):
        
        evals,evecs=find_evals_evec(n)
        
        for p in range(1,p_max+1,2):
            
            filename = ("n"+str(n)+"_p"+str(p)+"_truncdim"+str(trunc_dim)+"_lam_max"+str(lam_max)
                   +"_mu_cutoff"+str(mu_cutoff)+"cp_table_ORBITAL")
            
            output_data = []
            
            for lam in range(lam_max+1):
                output_data.append(current_per_orbital_n_p_lam(n, p, lam, evals, evecs, mu_cutoff))
                
            with open(filename, "w") as f:
                json.dump(output_data, f)

# %%
write_current_per_orbital(8,5,3)

# %%
write_current_per_orbital(8,5,3, mu_cutoff=50)

# %% [markdown]
# ## Plots
# ### Import Data

# %%
def read_cp_table_ORBITAL(n, p, lam_max=3, mu_cutoff=20, trunc_dim=100):
    
    filename = ("n"+str(n)+"_p"+str(p)+"_truncdim"+str(trunc_dim)+"_lam_max"+str(lam_max)
                   +"_mu_cutoff"+str(mu_cutoff)+"cp_table_ORBITAL")
    
    with open(filename) as f:
        cp_table = json.load(f)
    
    return cp_table

# %% [markdown]
# ### Plot single cp vs n

# %%
def plot_cp_vs_n_ORBITAL(n_max, p, ylim_in=False, lam_max=3, mu_cutoff=20, trunc_dim=100):
    
    cp_table_full = []
    cp_table_Landau = []
    
    for n in range(1,n_max+1):
        cp_row = read_cp_table_ORBITAL(n, p, lam_max=3, mu_cutoff=20, trunc_dim=100)
        cp_table_full.append(cp_row)
    
    for count in range(lam_max+1):
        cp_table_Landau.append([cp_table_full[0][count] for j in range(n_max)])
    
    
    cp_table_full = np.array(cp_table_full).T.tolist()
    
    nlist = [j for j in range(1,n_max+1)]
    
    colour_list=['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']
    
    plt.figure(figsize=(10,5))
    for count in range(lam_max+1):
        plt.plot(nlist, cp_table_Landau[count], ':', color=colour_list[count], label='|'+str(count)+'>, LL')
        plt.plot(nlist, cp_table_full[count], 'o', color=colour_list[count], label='|'+str(count)+'>')
    plt.legend(loc=5)
    plt.xlabel("n")
    plt.ylabel("coefficient")
    plt.xlim(0.75,n_max+1.5)
    if(ylim_in):
        plt.ylim(ylim_in[0],ylim_in[1])
    plt.title("Current per Orbital: c_"+str(p)+", mu_cutoff="+str(mu_cutoff)+", trunc_dim="+str(trunc_dim))

# %% [markdown]
# ### c_1

# %%
plot_cp_vs_n_ORBITAL(8,1, ylim_in=[0,2])

# %%
plot_cp_vs_n_ORBITAL(8,1, mu_cutoff=50, ylim_in=[0,2])

# %% [markdown]
# ### c_3

# %%
plot_cp_vs_n_ORBITAL(8,3)

# %%
plot_cp_vs_n_ORBITAL(8,3, mu_cutoff=50)

# %% [markdown]
# ### c_5

# %%
plot_cp_vs_n_ORBITAL(8,5)

# %%
plot_cp_vs_n_ORBITAL(8,5, mu_cutoff=50)
